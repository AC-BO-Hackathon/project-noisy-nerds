# %%
import seaborn as sn
import numpy as np
import torch
import pandas as pd

from src import visualization
import matplotlib.pyplot as plt

# %%
n_inits = [2, 4, 8, 10]
noise_levels = [1, 5, 10, 20]

n_inits = n_inits[::-1]

# %%
performance_matrix = np.zeros((len(n_inits), len(noise_levels)))

for i, init in enumerate(n_inits):
    for j, noise in enumerate(noise_levels):
        y_vals = torch.load(f'results/Schwe_n_init_{init}_noiselvl_{noise}_budget_30_seed_0_noise_True.pt')[1]
        best_y = torch.min(y_vals)
        performance_matrix[i,j] = best_y

# %%
fig, ax = plt.subplots()
visualization.grid_search_heatmap(n_inits, noise_levels, performance_matrix)
# Out:
# <Axes: xlabel='Noise level', ylabel='Number of BO iterations'>

# %%
plt.savefig('BAYBE_heatmap.png', dpi=300)

# %%
fig.savefig('BayBE_heatmap.png', dpi = 300)
